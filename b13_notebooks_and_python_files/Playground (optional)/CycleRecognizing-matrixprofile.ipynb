# %%
from matplotlib import pyplot as plt
import numpy as np
import matrixprofile as mp
import pandas

# %matplotlib inline

path = 'result/data_inside_20211017_160006.pkl.csv'

# %%
dataframe = pandas.read_csv(path) 
dataframe = dataframe.rename(columns={'Unnamed: 0':'timer'})
dataframe = dataframe.set_index(dataframe.timer)
dataframe = dataframe.drop('timer', axis=1)

date = dataframe.index[0]
dates = date.split()
date = dates[0]

#29 Zyklen lt. Produktionslogfile
dataframe = dataframe.loc[(dataframe.index >= date+' 18:27') & (dataframe.index < date+' 18:40')]
dataframe
# Out:
#                          accelerometer_x_max  accelerometer_y_max  \
# timer
# 2021-10-17 18:27:00.000            -6.889648             7.211914
# 2021-10-17 18:27:00.050            -6.909180             7.221680
# 2021-10-17 18:27:00.100            -6.850586             7.187500
# 2021-10-17 18:27:00.150            -6.904297             7.211914
# 2021-10-17 18:27:00.200            -6.293945             7.666016
# ...                                      ...                  ...
# 2021-10-17 18:39:59.750            -6.865234             7.231445
# 2021-10-17 18:39:59.800            -6.918945             7.182617
# 2021-10-17 18:39:59.850            -6.928711             7.260742
# 2021-10-17 18:39:59.900            -6.850586             7.250977
# 2021-10-17 18:39:59.950            -6.850586             7.177734
#
#                          accelerometer_z_max  accelerometer_x_min  \
# timer
# 2021-10-17 18:27:00.000             0.795898            -7.314453
# ...

# %%
plt.figure(figsize=(20,5))
plt.plot(np.arange(len(dataframe.index)), dataframe['magnetometer_x_mean'].values)
plt.title('magnetometer_x_mean')
plt.show()

# %%
profile, figures = mp.analyze(dataframe['magnetometer_x_mean'].values)
# Out:
# D:\Program Files\anaconda3\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# D:\Program Files\anaconda3\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# D:\Program Files\anaconda3\lib\site-packages\matrixprofile\visualize.py:433: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
profile = mp.compute(dataframe['magnetometer_x_mean'].values)
profile = mp.discover.motifs(profile)
profile
# Out:
# {'pmp': array([[0.78490459, 0.85678351, 0.79134698, ...,        inf,        inf,
#                 inf],
#         [1.14596824, 1.25865265, 0.95617083, ...,        inf,        inf,
#                 inf],
#         [1.26637346, 1.38014889, 1.07921425, ...,        inf,        inf,
#                 inf],
#         ...,
#         [4.00527516, 3.95307736, 3.95093251, ...,        inf,        inf,
#                 inf],
#         [4.1098897 , 4.22406997, 3.87842182, ...,        inf,        inf,
#                 inf],
#         [4.3026231 , 4.13291321, 3.9893469 , ...,        inf,        inf,
#                 inf]]),
#  'pmpi': array([[      10512,        9822,        1047, ..., -2147483648,
#          -2147483648, -2147483648],
#         [      13544,       10457,        1047, ..., -2147483648,
#          -2147483648, -2147483648],
#         [       9175,       13475,        1047, ..., -2147483648,
#          -2147483648, -2147483648],
#         ...,
# ...

# %%
profile['motifs']
# Out:
# [{'motifs': [(0, 6883), (0, 13939)], 'neighbors': [(0, 3537)]},
#  {'motifs': [(0, 8383), (0, 10229)], 'neighbors': []},
#  {'motifs': [(1, 6882), (1, 13938)], 'neighbors': [(1, 3536)]}]
