# %%
import pandas
import numpy
import datetime

path = 'WI3_BusinessIntelligence_Data_Bi3/data_outside_20211017_160006.pkl.csv'
ref_path = 'WI3_BusinessIntelligence_Data_Bi3/data_outside_20211017_160006.pkl.csv'

# %%
path = 'WI3_BusinessIntelligence_Data_Bi3/data_inside_20211016_000100.pkl.csv'
dataframe = pandas.read_csv(path) 
dataframe = dataframe.rename(columns={'Unnamed: 0':'timer'})
dataframe
# Out:
#                           timer  accelerometer_x_max  accelerometer_y_max  \
# 0       2021-10-17 16:00:06.000             0.512695            10.175781
# 1       2021-10-17 16:00:06.050             0.507812            10.185547
# 2       2021-10-17 16:00:06.100             0.546875            10.180664
# 3       2021-10-17 16:00:06.150             0.527344            10.161133
# 4       2021-10-17 16:00:06.200             0.541992            10.209961
# ...                         ...                  ...                  ...
# 574787  2021-10-17 23:59:05.350             0.903320            10.825195
# 574788  2021-10-17 23:59:05.400             0.654297            10.356445
# 574789  2021-10-17 23:59:05.450             0.654297            10.273438
# 574790  2021-10-17 23:59:05.500             0.566406            10.322266
# 574791  2021-10-17 23:59:05.550             0.566406            10.180664
#
#         accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 0                  0.136719             0.400391            10.073242
# 1                  0.141602             0.405273            10.097656
# 2                  0.161133             0.424805            10.078125
# 3                  0.112305             0.405273            10.083008
# 4                  0.117188             0.424805            10.083008
# ...                     ...                  ...                  ...
# 574787             0.439453             0.117188             9.624023
# 574788             0.927734             0.351562             9.892578
# 574789             0.673828             0.292969             9.960938
# 574790             0.288086             0.332031             9.941406
# 574791             0.170898             0.395508            10.107422
#
#         accelerometer_z_min  accelerometer_x_max_quantile  \
# 0                 -0.009766                      0.497559
# 1                  0.024414                      0.498047
# 2                 -0.019531                      0.527344
# 3                  0.019531                      0.507812
# 4                  0.004883                      0.517578
# ...                     ...                           ...
# 574787            -0.141602                      0.786133
# 574788            -0.922852                      0.600586
# 574789            -0.336914                      0.644531
# 574790            -0.122070                      0.541992
# 574791             0.039062                      0.562988
#
#         accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 0                          10.170898                      0.125977  ...
# 1                          10.180664                      0.112305  ...
# 2                          10.170898                      0.129883  ...
# 3                          10.151367                      0.107422  ...
# 4                          10.180664                      0.117188  ...
# ...                              ...                           ...  ...
# 574787                     10.493164                      0.322266  ...
# 574788                     10.249023                      0.878906  ...
# 574789                     10.234375                      0.541992  ...
# 574790                     10.285889                      0.244141  ...
# 574791                     10.180664                      0.160645  ...
#
#         accelerometer_y_min_quantile  accelerometer_z_min_quantile  \
# 0                          10.087891                      0.029297
# 1                          10.107422                      0.029785
# 2                          10.083008                      0.028564
# 3                          10.102539                      0.041016
# 4                          10.097656                      0.030273
# ...                              ...                           ...
# 574787                      9.760742                     -0.107422
# 574788                      9.941406                     -0.822754
# 574789                      9.965820                     -0.317383
# 574790                      9.959717                     -0.116455
# 574791                     10.107422                      0.039062
#
#         magnetometer_x_mean  magnetometer_y_mean  magnetometer_z_mean  \
# 0               -32368326.0           -5868932.0          -50881068.0
# 1               -32503676.0           -6088235.5          -49554536.0
# 2               -32374362.0           -5391581.5          -50213012.0
# 3               -32477632.0           -6436842.0          -50067104.0
# 4               -31673810.0           -5489285.5          -50334524.0
# ...                     ...                  ...                  ...
# 574787          -31969678.0           -4534034.5          -51444924.0
# 574788          -31872596.0           -4619591.5          -52894830.0
# 574789          -32144184.0           -4863861.5          -52512996.0
# 574790          -31956130.0           -4200721.0          -53171276.0
# 574791          -32187500.0           -6437500.0          -52468750.0
#
#         magnetometer_x_median  magnetometer_y_median  magnetometer_z_median  \
# 0                 -32375000.0             -5875000.0            -51687500.0
# 1                 -32375000.0             -5875000.0            -49750000.0
# 2                 -32000000.0             -5875000.0            -49781250.0
# 3                 -32375000.0             -6562500.0            -50562500.0
# 4                 -31250000.0             -5125000.0            -50187500.0
# ...                       ...                    ...                    ...
# 574787            -31812500.0             -4750000.0            -51625000.0
# 574788            -31812500.0             -4750000.0            -53250000.0
# 574789            -31437500.0             -4750000.0            -53250000.0
# 574790            -31812500.0             -4218750.0            -53437500.0
# 574791            -32187500.0             -6437500.0            -52468750.0
#
#         audio_max  audio_max_quantile
# 0        0.005737            0.004938
# 1        0.006104            0.004828
# 2        0.005768            0.004486
# 3        0.005219            0.004065
# 4        0.005798            0.004327
# ...           ...                 ...
# 574787   0.024078            0.018726
# 574788   0.017395            0.016406
# 574789   0.033142            0.024121
# 574790   0.033936            0.025244
# 574791   0.029297            0.025037
#
# [574792 rows x 21 columns]

# %%
date = dataframe.timer[0]
dates = date.split()
date = dates[0]

# %%
dataframe['cycle'] = None
dataframe
# Out:
#                           timer  accelerometer_x_max  accelerometer_y_max  \
# 0       2021-10-17 16:00:06.000             0.512695            10.175781
# 1       2021-10-17 16:00:06.050             0.507812            10.185547
# 2       2021-10-17 16:00:06.100             0.546875            10.180664
# 3       2021-10-17 16:00:06.150             0.527344            10.161133
# 4       2021-10-17 16:00:06.200             0.541992            10.209961
# ...                         ...                  ...                  ...
# 574787  2021-10-17 23:59:05.350             0.903320            10.825195
# 574788  2021-10-17 23:59:05.400             0.654297            10.356445
# 574789  2021-10-17 23:59:05.450             0.654297            10.273438
# 574790  2021-10-17 23:59:05.500             0.566406            10.322266
# 574791  2021-10-17 23:59:05.550             0.566406            10.180664
#
#         accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 0                  0.136719             0.400391            10.073242
# 1                  0.141602             0.405273            10.097656
# 2                  0.161133             0.424805            10.078125
# 3                  0.112305             0.405273            10.083008
# 4                  0.117188             0.424805            10.083008
# ...                     ...                  ...                  ...
# 574787             0.439453             0.117188             9.624023
# 574788             0.927734             0.351562             9.892578
# 574789             0.673828             0.292969             9.960938
# 574790             0.288086             0.332031             9.941406
# 574791             0.170898             0.395508            10.107422
#
#         accelerometer_z_min  accelerometer_x_max_quantile  \
# 0                 -0.009766                      0.497559
# 1                  0.024414                      0.498047
# 2                 -0.019531                      0.527344
# 3                  0.019531                      0.507812
# 4                  0.004883                      0.517578
# ...                     ...                           ...
# 574787            -0.141602                      0.786133
# 574788            -0.922852                      0.600586
# 574789            -0.336914                      0.644531
# 574790            -0.122070                      0.541992
# 574791             0.039062                      0.562988
#
#         accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 0                          10.170898                      0.125977  ...
# 1                          10.180664                      0.112305  ...
# 2                          10.170898                      0.129883  ...
# 3                          10.151367                      0.107422  ...
# 4                          10.180664                      0.117188  ...
# ...                              ...                           ...  ...
# 574787                     10.493164                      0.322266  ...
# 574788                     10.249023                      0.878906  ...
# 574789                     10.234375                      0.541992  ...
# 574790                     10.285889                      0.244141  ...
# 574791                     10.180664                      0.160645  ...
#
#         accelerometer_z_min_quantile  magnetometer_x_mean  \
# 0                           0.029297          -32368326.0
# 1                           0.029785          -32503676.0
# 2                           0.028564          -32374362.0
# 3                           0.041016          -32477632.0
# 4                           0.030273          -31673810.0
# ...                              ...                  ...
# 574787                     -0.107422          -31969678.0
# 574788                     -0.822754          -31872596.0
# 574789                     -0.317383          -32144184.0
# 574790                     -0.116455          -31956130.0
# 574791                      0.039062          -32187500.0
#
#         magnetometer_y_mean  magnetometer_z_mean  magnetometer_x_median  \
# 0                -5868932.0          -50881068.0            -32375000.0
# 1                -6088235.5          -49554536.0            -32375000.0
# 2                -5391581.5          -50213012.0            -32000000.0
# 3                -6436842.0          -50067104.0            -32375000.0
# 4                -5489285.5          -50334524.0            -31250000.0
# ...                     ...                  ...                    ...
# 574787           -4534034.5          -51444924.0            -31812500.0
# 574788           -4619591.5          -52894830.0            -31812500.0
# 574789           -4863861.5          -52512996.0            -31437500.0
# 574790           -4200721.0          -53171276.0            -31812500.0
# 574791           -6437500.0          -52468750.0            -32187500.0
#
#         magnetometer_y_median  magnetometer_z_median  audio_max  \
# 0                  -5875000.0            -51687500.0   0.005737
# 1                  -5875000.0            -49750000.0   0.006104
# 2                  -5875000.0            -49781250.0   0.005768
# 3                  -6562500.0            -50562500.0   0.005219
# 4                  -5125000.0            -50187500.0   0.005798
# ...                       ...                    ...        ...
# 574787             -4750000.0            -51625000.0   0.024078
# 574788             -4750000.0            -53250000.0   0.017395
# 574789             -4750000.0            -53250000.0   0.033142
# 574790             -4218750.0            -53437500.0   0.033936
# 574791             -6437500.0            -52468750.0   0.029297
#
#         audio_max_quantile  cycle
# 0                 0.004938   None
# 1                 0.004828   None
# 2                 0.004486   None
# 3                 0.004065   None
# 4                 0.004327   None
# ...                    ...    ...
# 574787            0.018726   None
# 574788            0.016406   None
# 574789            0.024121   None
# 574790            0.025244   None
# 574791            0.025037   None
#
# [574792 rows x 22 columns]

# %%
dataframe_pattern = pandas.read_csv(path, usecols=['magnetometer_z_median', 'Unnamed: 0']) 
dataframe_pattern = dataframe_pattern.rename(columns={'Unnamed: 0':'timer'})
dataframe_pattern = dataframe_pattern.set_index(dataframe_pattern.timer)
dataframe_pattern = dataframe_pattern.drop('timer', axis=1)

date = dataframe_pattern.index[0]
dates = date.split()
date = dates[0]

dataframe_pattern = dataframe_pattern.loc[(dataframe_pattern.index >= date+' 18:40:17.450') & (dataframe_pattern.index < date+' 18:40:36.050')]
dataframe_pattern
# Out:
#                          magnetometer_z_median
# timer
# 2021-10-17 18:40:17.450            -61187500.0
# 2021-10-17 18:40:17.500            -60375000.0
# 2021-10-17 18:40:17.550            -57312500.0
# 2021-10-17 18:40:17.600            -55312500.0
# 2021-10-17 18:40:17.650            -55750000.0
# ...                                        ...
# 2021-10-17 18:40:35.800            -49562500.0
# 2021-10-17 18:40:35.850            -51500000.0
# 2021-10-17 18:40:35.900            -53000000.0
# 2021-10-17 18:40:35.950            -57062500.0
# 2021-10-17 18:40:36.000            -61187500.0
#
# [372 rows x 1 columns]

# %%
pattern = list(dataframe_pattern.magnetometer_z_median.values)
pattern_len = len(pattern)
pattern_sum = sum(pattern)
pattern_sum
# Out:
# -17995375000.0

# %%
from datetime import datetime, timedelta
import difflib
start_time = dataframe.timer[0]
end_time = dataframe.timer.iloc[-1]
i = 0
df = pandas.DataFrame(columns=['timer', 'index', 'value', 'sum', 'len', 'sm'])
while i+400 < dataframe.index[-1]:
    part = dataframe[i+200:i+400]
    minindex = part['magnetometer_z_median'].idxmin()
    #print(minindex)
    minvalue = part['magnetometer_z_median'].min()
    #print(minvalue)
    dataframe_cycle = dataframe.loc[i:minindex]
    cycle = list(dataframe_cycle.magnetometer_z_median.values)
    sum_of_values = sum(cycle)
    ###
    time_start = datetime.strptime(start_time, '%Y-%m-%d %H:%M:%S.%f')
    time_end = datetime.strptime(dataframe.timer[minindex], '%Y-%m-%d %H:%M:%S.%f')
    len_of_cycle = time_end - time_start
    ###
    start_time = dataframe.timer[minindex]
    i = minindex
    ###
    #sm=difflib.SequenceMatcher(None, pattern, cycle)
    res = len(set(pattern) & set(cycle)) / float(len(set(pattern) | set(cycle)))
    #print(start_time)
    new_row = {'timer':start_time, 'index':minindex, 'value':minvalue, 'sum':sum_of_values+17995375000.0, 'len':len_of_cycle, 'sm':res}
    df = df.append(new_row, ignore_index=True)
df
# Out:
#                         timer   index       value           sum  \
# 0     2021-10-17 16:00:20.050     281 -52125000.0  3.802188e+09
# 1     2021-10-17 16:00:30.800     496 -52125000.0  7.125750e+09
# 2     2021-10-17 16:00:42.050     721 -52562500.0  6.602562e+09
# 3     2021-10-17 16:00:55.100     982 -52187500.0  4.806531e+09
# 4     2021-10-17 16:01:05.950    1199 -52562500.0  6.992719e+09
# ...                       ...     ...         ...           ...
# 1703  2021-10-17 23:57:44.700  573174 -62062500.0 -5.519688e+08
# 1704  2021-10-17 23:58:03.300  573546 -63250000.0 -5.875312e+08
# 1705  2021-10-17 23:58:21.900  573918 -63687500.0 -6.119688e+08
# 1706  2021-10-17 23:58:40.500  574290 -63312500.0 -6.135000e+08
# 1707  2021-10-17 23:58:59.100  574662 -64062500.0 -5.741250e+08
#
#                  len        sm
# 0    00:00:14.050000  0.000000
# 1    00:00:10.750000  0.000000
# 2    00:00:11.250000  0.000000
# 3    00:00:13.050000  0.000000
# 4    00:00:10.850000  0.000000
# ...              ...       ...
# 1703 00:00:18.550000  0.092437
# 1704 00:00:18.600000  0.086957
# 1705 00:00:18.600000  0.101695
# 1706 00:00:18.600000  0.100840
# 1707 00:00:18.600000  0.090164
#
# [1708 rows x 6 columns]

# %%
df2 = df.drop(df[df.value > -60000000.0].index)
#df2 = df.drop(df[df.sm < 0.01].index)
df2
# Out:
#                         timer   index       value           sum  \
# 637   2021-10-17 18:28:32.300  178126 -62937500.0 -1.665406e+09
# 638   2021-10-17 18:28:50.200  178484 -63687500.0  1.507812e+08
# 639   2021-10-17 18:29:08.800  178856 -63687500.0 -7.710938e+08
# 640   2021-10-17 18:29:27.400  179228 -61750000.0 -5.347812e+08
# 641   2021-10-17 18:29:45.950  179599 -62937500.0 -1.397188e+08
# ...                       ...     ...         ...           ...
# 1703  2021-10-17 23:57:44.700  573174 -62062500.0 -5.519688e+08
# 1704  2021-10-17 23:58:03.300  573546 -63250000.0 -5.875312e+08
# 1705  2021-10-17 23:58:21.900  573918 -63687500.0 -6.119688e+08
# 1706  2021-10-17 23:58:40.500  574290 -63312500.0 -6.135000e+08
# 1707  2021-10-17 23:58:59.100  574662 -64062500.0 -5.741250e+08
#
#                  len        sm
# 637  00:00:19.900000  0.036697
# 638  00:00:17.900000  0.043478
# 639  00:00:18.600000  0.039683
# 640  00:00:18.600000  0.031008
# 641  00:00:18.550000  0.024390
# ...              ...       ...
# 1703 00:00:18.550000  0.092437
# 1704 00:00:18.600000  0.086957
# 1705 00:00:18.600000  0.101695
# 1706 00:00:18.600000  0.100840
# 1707 00:00:18.600000  0.090164
#
# [1063 rows x 6 columns]

# %%
df2 = df2.drop(df2[df2.value > -60000000.0].index)
df2.head(20)
# Out:
#                        timer   index       value           sum  \
# 637  2021-10-17 18:28:32.300  178126 -62937500.0 -1.665406e+09
# 638  2021-10-17 18:28:50.200  178484 -63687500.0  1.507812e+08
# 639  2021-10-17 18:29:08.800  178856 -63687500.0 -7.710938e+08
# 640  2021-10-17 18:29:27.400  179228 -61750000.0 -5.347812e+08
# 641  2021-10-17 18:29:45.950  179599 -62937500.0 -1.397188e+08
# 642  2021-10-17 18:30:04.550  179971 -61000000.0 -2.212500e+08
# 643  2021-10-17 18:30:23.150  180343 -61375000.0 -1.798438e+08
# 644  2021-10-17 18:30:41.750  180715 -61750000.0 -2.443125e+08
# 645  2021-10-17 18:31:00.300  181086 -61000000.0 -1.522812e+08
# 646  2021-10-17 18:31:18.900  181458 -62562500.0 -2.011562e+08
# 647  2021-10-17 18:31:37.500  181830 -61812500.0 -1.934375e+08
# 648  2021-10-17 18:31:56.050  182201 -61000000.0 -3.436562e+08
# 649  2021-10-17 18:32:14.650  182573 -62562500.0 -7.443750e+07
# 650  2021-10-17 18:32:33.250  182945 -61437500.0 -9.343750e+07
# 651  2021-10-17 18:32:51.800  183316 -61062500.0 -1.521875e+07
# 652  2021-10-17 18:33:10.400  183688 -61812500.0 -5.956250e+07
# 653  2021-10-17 18:33:28.950  184059 -60625000.0  1.596875e+07
# 654  2021-10-17 18:33:47.550  184431 -61062500.0 -3.375000e+07
# 655  2021-10-17 18:34:06.150  184803 -61062500.0 -2.409375e+07
# 656  2021-10-17 18:34:24.700  185174 -62625000.0  1.718750e+07
#
#                 len        sm
# 637 00:00:19.900000  0.036697
# 638 00:00:17.900000  0.043478
# 639 00:00:18.600000  0.039683
# 640 00:00:18.600000  0.031008
# 641 00:00:18.550000  0.024390
# 642 00:00:18.600000  0.022388
# 643 00:00:18.600000  0.007634
# 644 00:00:18.600000  0.024000
# 645 00:00:18.550000  0.008065
# 646 00:00:18.600000  0.021429
# 647 00:00:18.600000  0.007353
# 648 00:00:18.550000  0.014599
# 649 00:00:18.600000  0.000000
# 650 00:00:18.600000  0.000000
# 651 00:00:18.550000  0.000000
# 652 00:00:18.600000  0.000000
# 653 00:00:18.550000  0.000000
# 654 00:00:18.600000  0.000000
# 655 00:00:18.600000  0.000000
# 656 00:00:18.550000  0.000000

# %%
dataframe_cycle = dataframe.loc[281:496]
dataframe_cycle
# Out:
#                        timer  accelerometer_x_max  accelerometer_y_max  \
# 281  2021-10-17 16:00:20.050             0.546875            10.180664
# 282  2021-10-17 16:00:20.100             0.537109            10.185547
# 283  2021-10-17 16:00:20.150             0.532227            10.180664
# 284  2021-10-17 16:00:20.200             0.561523            10.166016
# 285  2021-10-17 16:00:20.250             0.532227            10.180664
# ..                       ...                  ...                  ...
# 492  2021-10-17 16:00:30.600             0.541992            10.180664
# 493  2021-10-17 16:00:30.650             0.512695            10.185547
# 494  2021-10-17 16:00:30.700             0.551758            10.185547
# 495  2021-10-17 16:00:30.750             0.541992            10.185547
# 496  2021-10-17 16:00:30.800             0.551758            10.166016
#
#      accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 281             0.141602             0.395508            10.097656
# 282             0.146484             0.405273            10.087891
# 283             0.117188             0.395508            10.092773
# 284             0.126953             0.415039            10.048828
# 285             0.126953             0.390625            10.073242
# ..                   ...                  ...                  ...
# 492             0.112305             0.424805            10.092773
# 493             0.131836             0.405273            10.087891
# 494             0.136719             0.400391            10.092773
# 495             0.131836             0.390625            10.097656
# 496             0.126953             0.405273            10.087891
#
#      accelerometer_z_min  accelerometer_x_max_quantile  \
# 281             0.009766                      0.518311
# 282            -0.004883                      0.517578
# 283             0.000000                      0.527344
# 284             0.024414                      0.517578
# 285            -0.009766                      0.512695
# ..                   ...                           ...
# 492             0.004883                      0.522461
# 493            -0.019531                      0.503418
# 494             0.009766                      0.507324
# 495            -0.039062                      0.516846
# 496             0.000000                      0.512695
#
#      accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 281                     10.171631                      0.122070  ...
# 282                     10.172119                      0.097656  ...
# 283                     10.170898                      0.112305  ...
# 284                     10.161133                      0.122070  ...
# 285                     10.170898                      0.117188  ...
# ..                            ...                           ...  ...
# 492                     10.166016                      0.107422  ...
# 493                     10.175781                      0.126953  ...
# 494                     10.161133                      0.112305  ...
# 495                     10.170898                      0.114990  ...
# 496                     10.161133                      0.117188  ...
#
#      accelerometer_z_min_quantile  magnetometer_x_mean  magnetometer_y_mean  \
# 281                      0.019531          -33188138.0           -5512755.0
# 282                      0.019531          -32180990.0           -5914062.5
# 283                      0.024414          -32149134.0           -6340965.5
# 284                      0.034180          -32978092.0           -5878866.0
# 285                      0.034180          -32480000.0           -4947500.0
# ..                            ...                  ...                  ...
# 492                      0.029297          -32475962.0           -6331130.0
# 493                      0.014648          -32706876.0           -6520625.0
# 494                      0.019531          -32273666.0           -6231796.0
# 495                      0.024414          -32512620.0           -6871394.0
# 496                      0.008545          -32132076.0           -5434552.0
#
#      magnetometer_z_mean  magnetometer_x_median  magnetometer_y_median  \
# 281          -51322704.0            -32937500.0             -5500000.0
# 282          -50764324.0            -32375000.0             -6031250.0
# 283          -50873144.0            -32375000.0             -6187500.0
# 284          -49806700.0            -32750000.0             -6187500.0
# 285          -50218750.0            -32375000.0             -4750000.0
# ..                   ...                    ...                    ...
# 492          -50533652.0            -32375000.0             -6187500.0
# 493          -51103124.0            -32750000.0             -6937500.0
# 494          -50192960.0            -32750000.0             -6187500.0
# 495          -50521636.0            -32750000.0             -6562500.0
# 496          -51513560.0            -32000000.0             -5875000.0
#
#      magnetometer_z_median  audio_max  audio_max_quantile  cycle
# 281            -52125000.0   0.005890            0.004846   None
# 282            -50812500.0   0.007324            0.004816   None
# 283            -50625000.0   0.007782            0.005731   None
# 284            -49437500.0   0.007111            0.005743   None
# 285            -50250000.0   0.006866            0.005115   None
# ..                     ...        ...                 ...    ...
# 492            -50625000.0   0.006287            0.004852   None
# 493            -50625000.0   0.005798            0.005035   None
# 494            -51375000.0   0.006531            0.005359   None
# 495            -51375000.0   0.006744            0.005115   None
# 496            -52125000.0   0.006073            0.004950   None
#
# [216 rows x 22 columns]

# %%
cycle = list(dataframe_cycle.magnetometer_z_median.values)
cycle_len = len(cycle)
cycle_sum = sum(cycle)
cycle_sum
# Out:
# -10869625000.0

# %%
pattern_sum-cycle_sum
# Out:
# -7125750000.0

# %%
dataframe_cycle2 = dataframe.loc[178126:178484]
dataframe_cycle2
# Out:
#                           timer  accelerometer_x_max  accelerometer_y_max  \
# 178126  2021-10-17 18:28:32.300             0.556641            10.214844
# 178127  2021-10-17 18:28:32.350             0.585938            10.239258
# 178128  2021-10-17 18:28:32.400             0.537109            10.214844
# 178129  2021-10-17 18:28:32.450             0.541992            10.224609
# 178130  2021-10-17 18:28:32.500             0.551758            10.200195
# ...                         ...                  ...                  ...
# 178480  2021-10-17 18:28:50.000             0.532227            10.190430
# 178481  2021-10-17 18:28:50.050             0.537109            10.200195
# 178482  2021-10-17 18:28:50.100             0.522461            10.190430
# 178483  2021-10-17 18:28:50.150             0.522461            10.161133
# 178484  2021-10-17 18:28:50.200             0.541992            10.185547
#
#         accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 178126             0.136719             0.380859            10.083008
# 178127             0.156250             0.405273            10.063477
# 178128             0.141602             0.410156            10.073242
# 178129             0.141602             0.400391            10.068359
# 178130             0.136719             0.366211            10.087891
# ...                     ...                  ...                  ...
# 178480             0.117188             0.400391            10.092773
# 178481             0.131836             0.395508            10.087891
# 178482             0.151367             0.400391            10.063477
# 178483             0.141602             0.395508            10.083008
# 178484             0.117188             0.424805            10.092773
#
#         accelerometer_z_min  accelerometer_x_max_quantile  \
# 178126             0.009766                      0.512695
# 178127             0.019531                      0.546875
# 178128            -0.029297                      0.503418
# 178129            -0.029297                      0.537109
# 178130            -0.014648                      0.546875
# ...                     ...                           ...
# 178480             0.004883                      0.513184
# 178481            -0.024414                      0.508301
# 178482             0.004883                      0.517578
# 178483             0.009766                      0.512695
# 178484             0.004883                      0.502930
#
#         accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 178126                     10.195312                      0.126953  ...
# 178127                     10.205078                      0.145020  ...
# 178128                     10.195312                      0.117188  ...
# 178129                     10.161377                      0.127197  ...
# 178130                     10.190430                      0.131836  ...
# ...                              ...                           ...  ...
# 178480                     10.176025                      0.107422  ...
# 178481                     10.181641                      0.126953  ...
# 178482                     10.190430                      0.136719  ...
# 178483                     10.156250                      0.126953  ...
# 178484                     10.171143                      0.102539  ...
#
#         accelerometer_z_min_quantile  magnetometer_x_mean  \
# 178126                      0.014648          -33673890.0
# 178127                      0.029785          -33853764.0
# 178128                      0.034180          -33063132.0
# 178129                      0.019531          -33250000.0
# 178130                      0.000000          -32571338.0
# ...                              ...                  ...
# 178480                      0.029297          -33495624.0
# 178481                      0.014648          -33950130.0
# 178482                      0.028320          -34642044.0
# 178483                      0.009766          -33968136.0
# 178484                      0.024414          -33702500.0
#
#         magnetometer_y_mean  magnetometer_z_mean  magnetometer_x_median  \
# 178126           -6719678.0          -62707300.0            -33875000.0
# 178127           -5293082.5          -63209344.0            -33875000.0
# 178128           -5571338.5          -62153410.0            -32375000.0
# 178129           -5555000.0          -59412500.0            -33125000.0
# 178130           -5744949.5          -57030936.0            -32375000.0
# ...                     ...                  ...                    ...
# 178480           -5678750.0          -53353750.0            -33500000.0
# 178481           -6584596.0          -52807450.0            -33875000.0
# 178482           -6362373.5          -58339650.0            -35687500.0
# 178483           -5337010.0          -63047180.0            -33875000.0
# 178484           -5107500.0          -63426876.0            -33875000.0
#
#         magnetometer_y_median  magnetometer_z_median  audio_max  \
# 178126             -6937500.0            -62937500.0   0.015656
# 178127             -5875000.0            -62500000.0   0.014740
# 178128             -5125000.0            -61375000.0   0.014069
# 178129             -5875000.0            -58687500.0   0.015564
# 178130             -5125000.0            -56750000.0   0.021454
# ...                       ...                    ...        ...
# 178480             -5875000.0            -53625000.0   0.019562
# 178481             -6562500.0            -52875000.0   0.014923
# 178482             -6187500.0            -58687500.0   0.022278
# 178483             -5125000.0            -62937500.0   0.019836
# 178484             -5125000.0            -63687500.0   0.018585
#
#         audio_max_quantile  cycle
# 178126            0.012134   None
# 178127            0.012402   None
# 178128            0.011914   None
# 178129            0.012848   None
# 178130            0.012872   None
# ...                    ...    ...
# 178480            0.014807   None
# 178481            0.012408   None
# 178482            0.015308   None
# 178483            0.016406   None
# 178484            0.014581   None
#
# [359 rows x 22 columns]

# %%
cycle2 = list(dataframe_cycle2.magnetometer_z_median.values)
cycle_len2 = len(cycle2)
cycle_sum2 = sum(cycle2)
cycle_sum2
# Out:
# -17844593750.0

# %%
import difflib
sm=difflib.SequenceMatcher(None, pattern, cycle2)
sm.ratio()
# Out:
# 0.013679890560875513

# %%
sm=difflib.SequenceMatcher(None, pattern, cycle)
sm.ratio()
# Out:
# 0.0

# %%
res = len(set(pattern) & set(cycle)) / float(len(set(pattern) | set(cycle)))
res
# Out:
# 0.0

# %%
res = len(set(pattern) & set(cycle2)) / float(len(set(pattern) | set(cycle2)))
res
# Out:
# 0.043478260869565216

# %%
#df2.to_csv('result.csv')
from datetime import datetime, timedelta
time = datetime.strptime('2021-10-17 18:40:00.000', '%Y-%m-%d %H:%M:%S.%f')
time
# Out:
# datetime.datetime(2021, 10, 17, 18, 40)

# %%
x = time + timedelta(seconds=10)
x
# Out:
# datetime.datetime(2021, 10, 17, 18, 40, 10)

# %%
date_time = x.strftime('%Y-%m-%d %H:%M:%S.%f')
date_time
# Out:
# '2021-10-17 18:40:10.000000'

# %%
import stumpy
matches = stumpy.match(dataframe_pattern['magnetometer_z_median'], dataframe['magnetometer_z_median'])
matches
# Out:
# array([[2.9026299263384213e-06, 192229],
#        [4.721105132594272, 548986],
#        [4.729231274650847, 189259],
#        ...,
#        [16.064369024762474, 228290],
#        [16.078474954174183, 226189],
#        [16.205471448453572, 177653]], dtype=object)

# %%
matches = matches[matches[:, 0] < 10]
len(matches)
# Out:
# 1052

# %%
sorted_matches = sorted(matches, key=lambda x: x[1])

# %%
match_df = pandas.DataFrame(columns=['near', 'index'])
index = 0
while index < len(sorted_matches):
    near = sorted_matches[index][0]
    global_index = sorted_matches[index][1]
    '''match_distance = None
    if index+1 < len(sorted_matches):
        match_distance = sorted_matches[index+1][1] - sorted_matches[index][1]
    else:
        match_distance = dataframe.index[-1] - sorted_matches[index][1]'''
    new_row = {'near':near, 'index':global_index}
    match_df = match_df.append(new_row, ignore_index=True)
    index += 1
match_df
# Out:
#           near     index
# 0     5.578806  178484.0
# 1     6.079481  178856.0
# 2     5.244140  179228.0
# 3     5.218753  179599.0
# 4     5.145349  179971.0
# ...        ...       ...
# 1047  5.103609  572802.0
# 1048  5.538971  573174.0
# 1049  5.572260  573546.0
# 1050  5.479948  573918.0
# 1051  5.181876  574290.0
#
# [1052 rows x 2 columns]

# %%
match_df['distance'] = match_df['index'].shift(-1).sub(match_df['index'])
match_df
# Out:
#           near     index  distance
# 0     5.578806  178484.0     372.0
# 1     6.079481  178856.0     372.0
# 2     5.244140  179228.0     371.0
# 3     5.218753  179599.0     372.0
# 4     5.145349  179971.0     372.0
# ...        ...       ...       ...
# 1047  5.103609  572802.0     372.0
# 1048  5.538971  573174.0     372.0
# 1049  5.572260  573546.0     372.0
# 1050  5.479948  573918.0     372.0
# 1051  5.181876  574290.0       NaN
#
# [1052 rows x 3 columns]

# %%
last_index = int(match_df['index'].iloc[-1])
last_index
# Out:
# 574290

# %%
part = dataframe[last_index+200:last_index+400]
minindex = part['magnetometer_z_median'].idxmin()
minindex
# Out:
# 574662

# %%
minindex = dataframe.magnetometer_z_median[last_index+200:last_index+400].idxmin()
minindex
# Out:
# 574662

# %%
match_df['distance'].iloc[-1] = minindex-last_index
match_df
# Out:
#           near     index  distance
# 0     5.578806  178484.0     372.0
# 1     6.079481  178856.0     372.0
# 2     5.244140  179228.0     371.0
# 3     5.218753  179599.0     372.0
# 4     5.145349  179971.0     372.0
# ...        ...       ...       ...
# 1047  5.103609  572802.0     372.0
# 1048  5.538971  573174.0     372.0
# 1049  5.572260  573546.0     372.0
# 1050  5.479948  573918.0     372.0
# 1051  5.181876  574290.0     372.0
#
# [1052 rows x 3 columns]

# %%
match_df.nlargest(10, ['distance'])
# Out:
#          near     index  distance
# 124  5.667261  224497.0    5208.0
# 687  5.837062  438484.0     744.0
# 12   5.339641  182944.0     373.0
# 486  5.552192  363740.0     373.0
# 498  5.416013  368205.0     373.0
# 505  5.984819  370810.0     373.0
# 516  5.778819  374903.0     373.0
# 520  5.687670  376392.0     373.0
# 539  5.470018  383460.0     373.0
# 554  5.592766  389038.0     373.0

# %%
match_df_cleaned = match_df.drop(match_df[match_df.distance > 400].index)
match_df_cleaned = match_df_cleaned.drop(match_df_cleaned[match_df_cleaned.distance < 340].index)
match_df_cleaned.nlargest(10, ['distance'])
# Out:
#          near     index  distance
# 12   5.339641  182944.0     373.0
# 486  5.552192  363740.0     373.0
# 498  5.416013  368205.0     373.0
# 505  5.984819  370810.0     373.0
# 516  5.778819  374903.0     373.0
# 520  5.687670  376392.0     373.0
# 539  5.470018  383460.0     373.0
# 554  5.592766  389038.0     373.0
# 654  5.780745  426213.0     373.0
# 656  5.911212  426957.0     373.0

# %%
match_df.nsmallest(10, ['distance'])
# Out:
#          near     index  distance
# 11   5.598123  182574.0     370.0
# 59   5.292318  200394.0     370.0
# 67   4.939578  203362.0     370.0
# 80   5.448823  208184.0     370.0
# 82   5.457191  208926.0     370.0
# 86   5.329236  210409.0     370.0
# 94   5.240178  213376.0     370.0
# 100  5.413839  215601.0     370.0
# 105  5.422486  217455.0     370.0
# 107  5.283861  218196.0     370.0

# %%
match_df
# Out:
#           near     index  distance
# 0     5.578806  178484.0     372.0
# 1     6.079481  178856.0     372.0
# 2     5.244140  179228.0     371.0
# 3     5.218753  179599.0     372.0
# 4     5.145349  179971.0     372.0
# ...        ...       ...       ...
# 1047  5.103609  572802.0     372.0
# 1048  5.538971  573174.0     372.0
# 1049  5.572260  573546.0     372.0
# 1050  5.479948  573918.0     372.0
# 1051  5.181876  574290.0     372.0
#
# [1052 rows x 3 columns]

# %%
dataframe['cycle'] = None
for match in matches:
    if match[0] < 10:
        dataframe.at[match[1], 'cycle']='True'
dataframe_x = dataframe
dataframe_x = dataframe_x.dropna()
dataframe_x
# Out:
#                           timer  accelerometer_x_max  accelerometer_y_max  \
# 178484  2021-10-17 18:28:50.200             0.541992            10.185547
# 178856  2021-10-17 18:29:08.800             0.527344            10.195312
# 179228  2021-10-17 18:29:27.400             0.541992            10.185547
# 179599  2021-10-17 18:29:45.950             0.541992            10.205078
# 179971  2021-10-17 18:30:04.550             0.517578            10.219727
# ...                         ...                  ...                  ...
# 572802  2021-10-17 23:57:26.100             0.556641            10.190430
# 573174  2021-10-17 23:57:44.700             0.551758            10.156250
# 573546  2021-10-17 23:58:03.300             0.537109            10.205078
# 573918  2021-10-17 23:58:21.900             0.541992            10.166016
# 574290  2021-10-17 23:58:40.500             0.556641            10.156250
#
#         accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 178484             0.117188             0.424805            10.092773
# 178856             0.136719             0.385742            10.087891
# 179228             0.151367             0.390625            10.102539
# 179599             0.126953             0.410156            10.078125
# 179971             0.126953             0.380859            10.083008
# ...                     ...                  ...                  ...
# 572802             0.185547             0.419922            10.029297
# 573174             0.200195             0.400391            10.024414
# 573546             0.214844             0.424805            10.053711
# 573918             0.214844             0.424805            10.048828
# 574290             0.190430             0.390625            10.058594
#
#         accelerometer_z_min  accelerometer_x_max_quantile  \
# 178484             0.004883                      0.502930
# 178856            -0.009766                      0.511719
# 179228            -0.019531                      0.512695
# 179599            -0.009766                      0.527344
# 179971             0.004883                      0.512695
# ...                     ...                           ...
# 572802             0.048828                      0.534180
# 573174             0.053711                      0.527344
# 573546             0.078125                      0.527344
# 573918             0.048828                      0.533203
# 574290             0.048828                      0.537109
#
#         accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 178484                     10.171143                      0.102539  ...
# 178856                     10.169922                      0.126953  ...
# 179228                     10.175781                      0.112305  ...
# 179599                     10.185547                      0.112305  ...
# 179971                     10.180176                      0.116699  ...
# ...                              ...                           ...  ...
# 572802                     10.175781                      0.185547  ...
# 573174                     10.156250                      0.180664  ...
# 573546                     10.166016                      0.190430  ...
# 573918                     10.151367                      0.190430  ...
# 574290                     10.146484                      0.185547  ...
#
#         accelerometer_z_min_quantile  magnetometer_x_mean  \
# 178484                      0.024414          -33702500.0
# 178856                      0.019531          -32869642.0
# 179228                      0.029053          -33668750.0
# 179599                     -0.004883          -33201822.0
# 179971                      0.024414          -33510922.0
# ...                              ...                  ...
# 572802                      0.072266          -33400252.0
# 573174                      0.092773          -33561264.0
# 573546                      0.083008          -33535540.0
# 573918                      0.083008          -33061868.0
# 574290                      0.073242          -33590690.0
#
#         magnetometer_y_mean  magnetometer_z_mean  magnetometer_x_median  \
# 178484           -5107500.0          -63426876.0            -33875000.0
# 178856           -5646428.5          -63524404.0            -32375000.0
# 179228           -5227500.0          -61792500.0            -33500000.0
# 179599           -5998698.0          -62228516.0            -33125000.0
# 179971           -5600728.0          -61334950.0            -33500000.0
# ...                     ...                  ...                    ...
# 572802           -5437500.0          -62046084.0            -33625000.0
# 573174           -5127475.0          -61896660.0            -33625000.0
# 573546           -5878676.5          -63871324.0            -33250000.0
# 573918           -6079545.5          -63675504.0            -32937500.0
# 574290           -5747549.0          -62811276.0            -33250000.0
#
#         magnetometer_y_median  magnetometer_z_median  audio_max  \
# 178484             -5125000.0            -63687500.0   0.018585
# 178856             -5875000.0            -63687500.0   0.014526
# 179228             -5500000.0            -61750000.0   0.016052
# 179599             -5875000.0            -62937500.0   0.015350
# 179971             -5500000.0            -61000000.0   0.015533
# ...                       ...                    ...        ...
# 572802             -5500000.0            -62062500.0   0.024261
# 573174             -5125000.0            -62062500.0   0.018524
# 573546             -5875000.0            -63250000.0   0.028320
# 573918             -6625000.0            -63687500.0   0.023651
# 574290             -5500000.0            -63312500.0   0.019135
#
#         audio_max_quantile  cycle
# 178484            0.014581   True
# 178856            0.011133   True
# 179228            0.014172   True
# 179599            0.012689   True
# 179971            0.013287   True
# ...                    ...    ...
# 572802            0.018933   True
# 573174            0.012939   True
# 573546            0.020520   True
# 573918            0.021246   True
# 574290            0.016724   True
#
# [1052 rows x 22 columns]

# %%
dataframe_y = dataframe_x.loc[dataframe_x.timer >= '2021-10-17 18:32:00.000']
dataframe_y.head(10)
# Out:
#                           timer  accelerometer_x_max  accelerometer_y_max  \
# 182574  2021-10-17 18:32:14.700             0.590820            10.209961
# 182944  2021-10-17 18:32:33.200             0.537109            10.195312
# 183317  2021-10-17 18:32:51.850             0.561523            10.209961
# 183688  2021-10-17 18:33:10.400             0.517578            10.209961
# 184059  2021-10-17 18:33:28.950             0.541992            10.200195
# 184431  2021-10-17 18:33:47.550             0.541992            10.219727
# 184802  2021-10-17 18:34:06.100             0.522461            10.190430
# 185174  2021-10-17 18:34:24.700             0.517578            10.180664
# 185545  2021-10-17 18:34:43.250             0.507812            10.190430
# 185917  2021-10-17 18:35:01.850             0.590820            10.200195
#
#         accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 182574             0.166016             0.415039            10.087891
# 182944             0.146484             0.410156            10.087891
# 183317             0.161133             0.405273            10.043945
# 183688             0.136719             0.419922            10.068359
# 184059             0.136719             0.415039            10.073242
# 184431             0.126953             0.395508            10.063477
# 184802             0.146484             0.380859            10.083008
# 185174             0.122070             0.390625            10.083008
# 185545             0.136719             0.390625            10.083008
# 185917             0.146484             0.410156            10.073242
#
#         accelerometer_z_min  accelerometer_x_max_quantile  \
# 182574             0.004883                      0.541992
# 182944             0.004883                      0.527344
# 183317            -0.014648                      0.532227
# 183688             0.014648                      0.505615
# 184059             0.000000                      0.532227
# 184431             0.024414                      0.532227
# 184802             0.009766                      0.514160
# 185174            -0.009766                      0.517578
# 185545            -0.009766                      0.502930
# 185917             0.004883                      0.524902
#
#         accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 182574                     10.209473                      0.117188  ...
# 182944                     10.183594                      0.120117  ...
# 183317                     10.190430                      0.131836  ...
# 183688                     10.173584                      0.122070  ...
# 184059                     10.186035                      0.117432  ...
# 184431                     10.186279                      0.112305  ...
# 184802                     10.173340                      0.126953  ...
# 185174                     10.174805                      0.116699  ...
# 185545                     10.185547                      0.122559  ...
# 185917                     10.185547                      0.141602  ...
#
#         accelerometer_z_min_quantile  magnetometer_x_mean  \
# 182574                      0.015137          -33438112.0
# 182944                      0.012695          -35290028.0
# 183317                      0.004883          -33610148.0
# 183688                      0.019531          -34315972.0
# 184059                      0.000000          -34753750.0
# 184431                      0.043945          -33455128.0
# 184802                      0.034180          -34748028.0
# 185174                      0.024414          -34121970.0
# 185545                      0.024414          -34038510.0
# 185917                      0.028076          -33496710.0
#
#         magnetometer_y_mean  magnetometer_z_mean  magnetometer_x_median  \
# 182574           -5623162.0          -61556372.0            -33125000.0
# 182944           -6035112.5          -60654496.0            -35687500.0
# 183317           -6475247.5          -61090348.0            -34187500.0
# 183688           -5924305.5          -62179170.0            -33875000.0
# 184059           -6252500.0          -60566876.0            -34593750.0
# 184431           -6823718.0          -61201120.0            -33500000.0
# 184802           -5188816.0          -59897370.0            -34937500.0
# 185174           -5623179.5          -62532770.0            -34562500.0
# 185545           -6184974.5          -61224748.0            -33875000.0
# 185917           -6012335.5          -59802630.0            -33500000.0
#
#         magnetometer_y_median  magnetometer_z_median  audio_max  \
# 182574             -5875000.0            -61812500.0   0.012390
# 182944             -5875000.0            -61000000.0   0.013397
# 183317             -6187500.0            -61062500.0   0.019958
# 183688             -6562500.0            -61812500.0   0.014496
# 184059             -6187500.0            -60625000.0   0.014130
# 184431             -6937500.0            -61062500.0   0.014954
# 184802             -5500000.0            -59500000.0   0.012939
# 185174             -5875000.0            -62625000.0   0.011261
# 185545             -6187500.0            -61437500.0   0.015839
# 185917             -6187500.0            -60312500.0   0.011292
#
#         audio_max_quantile  cycle
# 182574            0.010638   True
# 182944            0.012262   True
# 183317            0.017767   True
# 183688            0.010382   True
# 184059            0.011401   True
# 184431            0.013123   True
# 184802            0.010535   True
# 185174            0.010297   True
# 185545            0.012335   True
# 185917            0.010736   True
#
# [10 rows x 22 columns]

# %%
i = 1
dataframe_y['cycle'].replace({'True': ++i}, inplace=True)
dataframe_y.head()
# Out:
# D:\Program Files\anaconda3\lib\site-packages\pandas\core\generic.py:6746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)
#                           timer  accelerometer_x_max  accelerometer_y_max  \
# 182574  2021-10-17 18:32:14.700             0.590820            10.209961
# 182944  2021-10-17 18:32:33.200             0.537109            10.195312
# 183317  2021-10-17 18:32:51.850             0.561523            10.209961
# 183688  2021-10-17 18:33:10.400             0.517578            10.209961
# 184059  2021-10-17 18:33:28.950             0.541992            10.200195
#
#         accelerometer_z_max  accelerometer_x_min  accelerometer_y_min  \
# 182574             0.166016             0.415039            10.087891
# 182944             0.146484             0.410156            10.087891
# 183317             0.161133             0.405273            10.043945
# 183688             0.136719             0.419922            10.068359
# 184059             0.136719             0.415039            10.073242
#
#         accelerometer_z_min  accelerometer_x_max_quantile  \
# 182574             0.004883                      0.541992
# 182944             0.004883                      0.527344
# 183317            -0.014648                      0.532227
# 183688             0.014648                      0.505615
# 184059             0.000000                      0.532227
#
#         accelerometer_y_max_quantile  accelerometer_z_max_quantile  ...  \
# 182574                     10.209473                      0.117188  ...
# 182944                     10.183594                      0.120117  ...
# 183317                     10.190430                      0.131836  ...
# 183688                     10.173584                      0.122070  ...
# 184059                     10.186035                      0.117432  ...
#
#         accelerometer_z_min_quantile  magnetometer_x_mean  \
# 182574                      0.015137          -33438112.0
# 182944                      0.012695          -35290028.0
# 183317                      0.004883          -33610148.0
# 183688                      0.019531          -34315972.0
# 184059                      0.000000          -34753750.0
#
#         magnetometer_y_mean  magnetometer_z_mean  magnetometer_x_median  \
# 182574           -5623162.0          -61556372.0            -33125000.0
# 182944           -6035112.5          -60654496.0            -35687500.0
# 183317           -6475247.5          -61090348.0            -34187500.0
# 183688           -5924305.5          -62179170.0            -33875000.0
# 184059           -6252500.0          -60566876.0            -34593750.0
#
#         magnetometer_y_median  magnetometer_z_median  audio_max  \
# 182574             -5875000.0            -61812500.0   0.012390
# 182944             -5875000.0            -61000000.0   0.013397
# 183317             -6187500.0            -61062500.0   0.019958
# 183688             -6562500.0            -61812500.0   0.014496
# 184059             -6187500.0            -60625000.0   0.014130
#
#         audio_max_quantile  cycle
# 182574            0.010638      1
# 182944            0.012262      1
# 183317            0.017767      1
# 183688            0.010382      1
# 184059            0.011401      1
#
# [5 rows x 22 columns]
